# %% [markdown]
# # static

# %% [markdown]
# Pandas provide high level data structure ans variety of analysis tool .
# It is use for data analysis , data manipulationsnd cleaning of data.
#
# Numpy - It Stands for numerical python.
# it is popular machine learning library that support its large matrixs and multidimentional data
#
# seaborn - Ploting heat map of the given data and try to understand the relationship between the variable
#
# matplotlib - ploting numeric data used in data analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import pickle

# %%
mall= pd.read_csv(r"C:\Users\User31\Desktop\Siddhi_Chavan\Stats\Mall_Customers.csv",index_col=0,header=0)
mall.head()
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40

# %%
print(mall.shape)
# Out:
# (200, 4)

# %%
print(mall.dtypes)
# Out:
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
print(mall.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  200 non-null    object
#  1   Age                     200 non-null    int64
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.8+ KB
# None

# %%
print(mall.tail())
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 196         Female   35                 120                      79
# 197         Female   45                 126                      28
# 198           Male   32                 126                      74
# 199           Male   32                 137                      18
# 200           Male   30                 137                      83

# %%
print(mall)
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40
# ...            ...  ...                 ...                     ...
# 196         Female   35                 120                      79
# 197         Female   45                 126                      28
# 198           Male   32                 126                      74
# 199           Male   32                 137                      18
# 200           Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
mall.describe()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000

# %%
mall.describe(include="all")
# Out:
#         Gender         Age  Annual Income (k$)  Spending Score (1-100)
# count      200  200.000000          200.000000              200.000000
# unique       2         NaN                 NaN                     NaN
# top     Female         NaN                 NaN                     NaN
# freq       112         NaN                 NaN                     NaN
# mean       NaN   38.850000           60.560000               50.200000
# std        NaN   13.969007           26.264721               25.823522
# min        NaN   18.000000           15.000000                1.000000
# 25%        NaN   28.750000           41.500000               34.750000
# 50%        NaN   36.000000           61.500000               50.000000
# 75%        NaN   49.000000           78.000000               73.000000
# max        NaN   70.000000          137.000000               99.000000

# %%
mall.isnull().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
X=mall.values[:,[2,3]] #indexing out put in form of array
X
# Out:
# array([[15, 39],
#        [15, 81],
#        [16, 6],
#        [16, 77],
#        [17, 40],
#        [17, 76],
#        [18, 6],
#        [18, 94],
#        [19, 3],
#        [19, 72],
#        [19, 14],
#        [19, 99],
#        [20, 15],
#        [20, 77],
#        [20, 13],
#        [20, 79],
#        [21, 35],
#        [21, 66],
#        [23, 29],
#        [23, 98],
#        [24, 35],
#        [24, 73],
#        [25, 5],
#        [25, 73],
#        [28, 14],
#        [28, 82],
#        [28, 32],
#        [28, 61],
#        [29, 31],
#        [29, 87],
#        [30, 4],
#        [30, 73],
#        [33, 4],
#        [33, 92],
#        [33, 14],
#        [33, 81],
#        [34, 17],
#        [34, 73],
#        [37, 26],
#        [37, 75],
#        [38, 35],
#        [38, 92],
#        [39, 36],
#        [39, 61],
#        [39, 28],
#        [39, 65],
#        [40, 55],
#        [40, 47],
#        [40, 42],
#        [40, 42],
#        [42, 52],
#        [42, 60],
# ...

# %%
mall.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Annual Income (k$)'}>],
#        [<Axes: title={'center': 'Spending Score (1-100)'}>, <Axes: >]],
#       dtype=object)
