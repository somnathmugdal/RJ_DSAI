# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import pickle

# %%
Advertising= pd.read_csv(r"C:\Users\User31\Desktop\Siddhi_Chavan\Stats\Advertising.csv",index_col=0,header=0)
Advertising.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
print(Advertising.shape)
# Out:
# (200, 4)

# %%
print(Advertising.dtypes)
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
Advertising.describe(include="all")# data mai repetation hoga to change hoga describe function se
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
Advertising.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
Advertising.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
Advertising.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
Advertising.boxplot()
plt.show()

# %%
#Check using boxplot
for i in Advertising.columns:
    Advertising.boxplot(column=i)
    plt.show()

# %% [markdown]
# # no outlier in data

# %%
for i in Advertising.columns:
    Advertising.hist(column=i)
    plt.show()

# %%
sns.pairplot(Advertising,x_vars=['TV','radio','newspaper'],
             y_vars="sales",kind='scatter')
plt.show()

# %%
sns.pairplot(Advertising,x_vars=['TV','radio','newspaper'],
             y_vars="sales",kind='reg')
plt.show()

# %% [markdown]
# difference between loc and iloc *note: always check shape

# %%
X=Advertising[['TV','radio','newspaper']]
Y= Advertising['sales']
#X= Advertising.iloc[;0:1] it  is used for large dataset
#Y= Advertising.iloc[:,-1] it  is used for large dataset

# %%
print(X.shape)
print(Y.shape)
# Out:
# (200, 3)
# (200,)

# %% [markdown]
# warning
# import warnings
# warnings:filterwarnings("ignore")

# %%
X.hist(bins=75) #bins is use for height in graph eg: 20 ,40 ,60 or 50 ,100, 150
plt.show()

# %%
corr_df=X.corr(method="pearson")
print(corr_df)
sns.heatmap(corr_df,vmax=1.0,vmin=0.1,annot=True,cmap='coolwarm')# try to change values
plt.show()
# Out:
#                  TV     radio  newspaper
# TV         1.000000  0.054809   0.056648
# radio      0.054809  1.000000   0.354104
# newspaper  0.056648  0.354104   1.000000

# %%
#Corelation 
corr_df=X.corr(method="pearson")
print(corr_df)
sns.heatmap(corr_df,vmax=1.0,vmin=1.0,annot=True,cmap='coolwarm')# try to change values
plt.show()
# Out:
#                  TV     radio  newspaper
# TV         1.000000  0.054809   0.056648
# radio      0.054809  1.000000   0.354104
# newspaper  0.056648  0.354104   1.000000

# %% [markdown]
# positive corelation in above graph
